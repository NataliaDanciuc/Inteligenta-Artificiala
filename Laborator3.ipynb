# %% [markdown]
# Șiruri de caractere (strings)

# %%
fruct= 'banana'
litera= fruct[1]
print(litera)
lungime=len(fruct)
ultim=fruct[lungime-1]
print(ultim)
# Out:
# a
# a

# %% [markdown]
# Parcurgerea unui șir de caractere cu o buclă

# %%
index=0
fruct= 'banana'
litera= fruct[1]
while index<len(fruct):
  litera=fruct[index]
  print(litera)
  index=index+1
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# Exercițiu:
# Scrieți o buclă while care începe cu ultimul caracter dintr-un string și îl parcurge în sens invers, afișând
# câte o literă pe câte o linie.

# %%
word = input('Insert a word:  ')
index = len(word)
while (index <= len(word)) & (index > 0):
    litera = word[index-1]
    print(litera)
    index = index - 1

# %%
fruct='banana'
reversedString=[]
index = len(fruct)
while index > 0:
  reversedString += fruct[index-1]
  index = index - 1
  print(reversedString)

fruct='portocala'
reversed=''.join(reversed(fruct))# .join() method merges all of the characters resulting from the reversed iteration into a new string
print(reversed)
# Out:
# ['a']
# ['a', 'i']
# ['a', 'i', 'l']
# ['a', 'i', 'l', 'a']
# ['a', 'i', 'l', 'a', 't']
# ['a', 'i', 'l', 'a', 't', 'a']
# ['a', 'i', 'l', 'a', 't', 'a', 'n']
# cuicnad

# %% [markdown]
# Felii de șiruri de caractere (Slices)
# are 2 parametrii (n,m) n- de unde porneste; m- unde se termina

# %%
s='Monty Python'
print(s[0:5])
print(s[6:12])
# Out:
# Monty
# Python

# %% [markdown]
# Operatorul [ ] returnează partea din șirul de caractere care începe cu al n-lea caracter, până la al m-lea
# caracter, incluzându-l pe primul, dar excluzându-l pe ultimul.
# Dacă omitem primul indice îninte de :, felia începe la începutul șirului de caractere. Dacă îl omitem pe al
# doilea, felia se va termina la capătul șirului de caractere
# Dacă primul indice este mai mare sau egal cu al doilea, rezultatul va fi un șir vid:

# %%
fruct='banana'
fruct[:3]
# Out:
# 'ban'

# %%
fruct='banana'
fruct[3:]
# Out:
# 'ana'

# %%
fruct='banana'
fruct[3:3]
# Out:
# ''

# %% [markdown]
# Numărarea caracterelor printr-o buclă

# %%
word='banana'
count=0;
for letter in word:
  if letter =='a':
    count=count+1
print(count)
# Out:
# 3

# %% [markdown]
# Exercițiu: Încapsulați secvența de cod de mai sus într-o funcție numităcount și generalizați-o astfel încât
# să accepte șirul de caractere și litera de numărat ca și argumente.

# %%
def count_word(word, lettertosearch):
  count=0
  for letter in word:
    if letter == lettertosearch:
      count=count+1
  print(count)
count_word('ananas','n')
# Out:
# 2

# %% [markdown]
# **Operatorul in**
# Operatorul in este un operator Boolean care ia valoarea True dacă primul șir de caractere este un subșir
# din al doilea:

# %%
'a' in 'banana'
# Out:
# True

# %%
'seed' in 'banana'
# Out:
# False

# %% [markdown]
# Compararea șirurilor

# %%
word=input('introdceti cuvantul: ')
if word < 'banana':
  print('Cuvantul, '+ word + ',este inainte de banana')
elif word > 'banana':
  print('Cuvantul, '+ word + ',este dupa banana')
else:
  print('Egaliatate')
# Out:
# introdceti cuvantulana
# Cuvantul, ana,este inainte de banana

# %% [markdown]
# **Metodele șirurilor de caractere**

# %%
word='banana'
type(word)
dir(word)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(str.capitalize)
# Out:
# Help on method_descriptor:
#
# capitalize(self, /)
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
word = 'banana'
index = word.find('a')
print(index)
# Out:
# 1

# %% [markdown]
# **Parsarea șirurilor de caractere**

# %% [markdown]
# Deseori este nevoie să verificăm apariția unui subșir intr-un șir. De exemplu avem următoarea linie:
# From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008
# Ne dorim să extragem domeniul adresei de email din această linie. Vom folosi următoarea secvență

# %%
data= 'From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008'
atpos = data.find('@')
print(atpos)
# Out:
# 21

# %% [markdown]
# **Operatorul de formatare**
# Operatorul de formatare % ne permite să construim șiruri de caractere prin înlocuirea unor părți ale lor
# cu date din variabile.

# %%
camile=42
print('Am vazut %d camile.'%camile)
# Out:
# Am vazut 42 camile.

# %% [markdown]
# Exerciții
# 1. Plecând de la următoarea instrucțiune folosiți metoda find și operațiunile de slice pentru a
# extrage partea de text de după “:” și folosiți apoi funcția float pentru a converti valoarea extrasă
# într-un număr real pe care să îl afișați.
# text = 'X-DSPAM-Confidence:0.8475'

# %%
text='X-DSPAM-Confidence:0.8475'
delimiterpos = text.find(':')
number = text[delimiterpos+1:]
print(float(number))
# Out:
# 0.8475

# %% [markdown]
# **Lucrul cu fișiere**

# %%
f= open('mbox.txt')
print(f)
# Out:
# <_io.TextIOWrapper name='mbox.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# **Fișierele text și liniile din fișier**
# Un fișier text este o secvență de linii de text, așa cum șirul de caractere este o secvență de caractere.
# Parcurgerea unui fișier se poate face folosind un ciclu for. De exemplu, pentru numărarea liniilor dintrun fișier folosim următorul cod:

# %%
f = open('mbox.txt')
count = 0
for line in f:
  count = count + 1
print('Nr linii:', count)
# Out:
# Nr linii: 132045

# %% [markdown]
# Pentru fișierele foarte mari, Python nu încarcă în memorie întreg fișierul la deschidere, iar ciclul for,
# parcurgând linie cu linie fișierul, reușește să il parcurgă într-un mod eficient, astfel încât să nu
# supraîncarce memoria internă.
# Pentru a încărca întreg fișierul în memorie, se poate folosi metoda read().

# %%
f=open('mbox-short.txt')
inp=f.read()
print(len(inp))
# Out:
# 94626

# %% [markdown]
# **Căutarea în fișiere**

# %%
f=open('mbox-short.txt')
count=0
for line in f:
  if line.startswith('From:'):
    print(line)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: gsilver@umich.edu
#
# From: gsilver@umich.edu
#
# From: zqian@umich.edu
#
# From: gsilver@umich.edu
#
# From: wagnermr@iupui.edu
#
# From: zqian@umich.edu
#
# From: antranig@caret.cam.ac.uk
#
# From: gopal.ramasammycook@gmail.com
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: louis@media.berkeley.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu

# %% [markdown]
# In afisare apare o spatiere suplimentara intre linii datorita faptului ca in fisier fiecare linie contine un caracter special
# \n care face sa se treaca la un rand nou la apelul functiei print. Pentru a evita acest efect, putem utiliza metoda rstrip,
# care elimina spatiile de la dreapta unui string:

# %% [markdown]
# **Scrierea în fișier**
# Pentru a putea scrie într-un fișier, acesta trebuie deschis folosind “w” ca și parametru:

# %%
fout = open('output.txt','w')
print(fout)
<_io.TextIOWrapper name='output.txt' mode='w' encoding='cp1252'>
# Out:
#   File "<ipython-input-4-60d97849b61f>", line 3
#     <_io.TextIOWrapper name='output.txt' mode='w' encoding='cp1252'>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2. Scrieti un program care citeste dintr-un fisier si cauta linii de forma:
# X-DSPAM-Confidence: 0.8475
# Cand intalniti o linie ce incepe cu “X-DSPAM-Confidence:” prelucrati acea linie si extrageti valoarea
# reală. Numărați aceste linii și calculați suma valorilor pentru spam confidence. Când ați ajuns la finalul
# fișierului afișați media spam confidence.

# %%
f=input('introduceti numele fisierului: ')
f=open('mbox-short.txt')
count=0
for line in f:
  if line.startswith('X-DSPAM-Confidence:'):
    count=count+1
print('nr linii care incep cu X-DSPAM-Confidence:', count)
# Out:
# introduceti numele fisierului: mbox.txt
# nr linii care incep cu X-DSPAM-Confidence: 27
