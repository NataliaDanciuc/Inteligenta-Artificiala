# %% [markdown]
# # laborator1

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Salvare date in cloud

# %%
print(4)
# Out:
# 4

# %%
type('Hello World')
# Out:
# str

# %%
type(3.2)
# Out:
# float

# %%
print(1,000,000)
# Out:
# 1 0 0

# %%
n = 17
pi = 3.1415926535897931
print(n)
print(pi)
# Out:
# 17
# 3.141592653589793

# %%
rest= 7 % 3
print(rest)
# Out:
# 1

# %%
primul=10
secund=15
print(primul+secund)
# Out:
# 25

# %%
primul='100'
secund='150'
print(primul+secund)
# Out:
# 100150

# %%
primul='Test'
secund=3
print(primul*secund)
# Out:
# TestTestTest

# %%
inp=input()
print (inp)
# Out:
# ana are mere
# ana are mere

# %% [markdown]
# Va permite utilizatorului să introducă un text de la tastatură si va afisa rezultatul

# %%
nume=input('Cum va numiti?\n')
print (nume)
# Out:
# Cum va numiti?
# Natalia
# Natalia

# %% [markdown]
# De obicei, este indicat să fie transmisă o indicaţie utilizatorului pentru a şti ce anume să introducă.

# %%
# calculeaza procentul dintr-o ora
minute= 60

percentage = (minute * 100) / 60
print(percentage)
# Out:
# 100.0

# %% [markdown]
# comentariile se fac cu # sau cu "" daca avem mai multe linii de comentat

# %% [markdown]
# EXERCITIUL 1

# %% [markdown]
# Scrieti un program care solicită utilizatorului introducerea de la tastatură a numărului de ore
# de lucru şi rata orară, calculând apoi salariul brut.

# %%
ore= input('Introduceti numearul de ore lucrate')
print (ore)
rata=input('Introduceti rata orala')
print (rata)

salariuBrut= print(int(ore)*int(rata))
# Out:
# Introduceti numearul de ore lucrate10
# 10
# Introduceti rata orala2
# 2
# 20

# %% [markdown]
# EXERCITIUL 2

# %% [markdown]
# Scrieti un program care solicita introducerea temperaturii în grade Celsius, o converteste în
# Fahrenheit si afiseaza valoarea transformata.

# %%
Celsius=input('Introduceti temperatura in grade Celsius ')
Fahrenheit= int(Celsius)*1.8+32
print('Temperatura in Fahrenheit este: ' ,Fahrenheit )
# Out:
# Introduceti temperatura in grade Celsius 20
# Temperatura in Fahrenheit este:  68.0

# %% [markdown]
# EXERCITIUL 3

# %% [markdown]
# Având urmatoarele atribuiri,
# latime=17
# inaltime=12.0
# scrieti valoarea expresiei si tipul rezultat:
# a. latime//2
# b. latime/2.0
# c. inaltime/3
# d. 1+2*5
#  Folositi interpretatorul Python pentru a verifica răspunsurile.

# %%
latime=17
inaltime=12.0
calc1=latime/2
print('valoare calcul 1: ', calc1 , type(calc1))
calc2=latime/2.0
print('valoare calcul 2: ', calc2, type(calc2))
calc3=inaltime/3
print('valoare calcul 3: ', calc3, type(calc3))
calc4=1+2*5


print('Variabila latime: ',latime, type(latime))
print('Variabila inaltime: ' ,inaltime, type(inaltime))
# Out:
# valoare calcul 1:  0.5 <class 'float'>
# valoare calcul 2:  8.5 <class 'float'>
# valoare calcul 3:  4.0 <class 'float'>
# Variabila latime:  17 <class 'int'>
# Variabila inaltime:  12.0 <class 'float'>
